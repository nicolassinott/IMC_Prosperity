# %%
import os 
if 'notebooks' in os.getcwd():
    os.chdir("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
prices = pd.read_csv(
    "data/round3/prices_round_3_day_0.csv",
    sep = ';'
)

# %%
prices
# Out:
#        day  timestamp            product  bid_price_1  bid_volume_1  \
# 0        0          0        DIVING_GEAR      99999.0           6.0
# 1        0          0             PEARLS       9998.0           1.0
# 2        0          0           COCONUTS       8113.0         205.0
# 3        0          0            BERRIES       3997.0          19.0
# 4        0          0            BANANAS       4893.0           1.0
# ...    ...        ...                ...          ...           ...
# 69995    0     999900            BERRIES       3917.0          16.0
# 69996    0     999900             PEARLS       9996.0           2.0
# 69997    0     999900            BANANAS       4870.0          23.0
# 69998    0     999900  DOLPHIN_SIGHTINGS          NaN           NaN
# 69999    0     999900       PINA_COLADAS      15011.0         108.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          99998.0          19.0          NaN           NaN     100001.0
# ...

# %%
dolphins = prices.query("product == 'DOLPHIN_SIGHTINS'")\
    .set_index("timestamp")
diving_gear = prices.query("product == 'DIVING_GEAR'")\
    .set_index("timestamp")

# %%
dolphins
# Out:
# Empty DataFrame
# Columns: [day, product, bid_price_1, bid_volume_1, bid_price_2, bid_volume_2, bid_price_3, bid_volume_3, ask_price_1, ask_volume_1, ask_price_2, ask_volume_2, ask_price_3, ask_volume_3, mid_price, profit_and_loss]
# Index: []
